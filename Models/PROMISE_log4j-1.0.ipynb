# %%
import pandas as pd
from scipy.io import arff
from sklearn.model_selection import train_test_split 
from models import Implicit_ME
from models import Logistic
from models import SVM
from models import DecisionTree
from models import Explicit_ME
from ensemble_models import adaBoost
from ensemble_models import bagging

# %%
data = arff.loadarff('../dataSet/PROMISE/log4j-1.0.arff')

# %%
df = pd.DataFrame(data[0])
df.head()
# Out:
#     wmc  dit  noc   cbo   rfc  lcom    ca   ce  npm     lcom3  ...       dam  \
# 0   4.0  4.0  0.0   3.0  12.0   6.0   2.0  1.0  4.0  2.000000  ...  0.000000
# 1   2.0  1.0  0.0   0.0   3.0   1.0   0.0  0.0  2.0  2.000000  ...  0.000000
# 2   8.0  1.0  0.0   6.0  22.0   0.0   3.0  3.0  8.0  0.142857  ...  1.000000
# 3   8.0  2.0  1.0   7.0  24.0  12.0   1.0  6.0  8.0  0.936508  ...  0.555556
# 4  10.0  1.0  5.0  34.0  13.0  45.0  32.0  2.0  9.0  1.000000  ...  0.000000
#
#    moa       mfa       cam   ic  cbm     amc  max_cc  avg_cc  defects
# 0  0.0  0.953488  0.357143  1.0  3.0  23.750     3.0   1.000      0.0
# 1  0.0  0.000000  0.500000  0.0  0.0   2.000     1.0   0.500      0.0
# 2  0.0  0.000000  0.406250  0.0  0.0  20.875     5.0   3.125      0.0
# 3  0.0  0.533333  0.333333  0.0  0.0  20.250     7.0   2.250      0.0
# 4  0.0  0.000000  0.407407  0.0  0.0   1.600     1.0   0.800      0.0
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#               wmc         dit         noc         cbo         rfc        lcom  \
# count  135.000000  135.000000  135.000000  135.000000  135.000000  135.000000
# mean     6.585185    1.600000    0.303704    6.859259   21.400000   19.933333
# std      5.633568    0.932018    1.108139    8.989349   17.513406   65.454234
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      4.000000    1.000000    0.000000    2.000000    9.000000    0.000000
# 50%      5.000000    1.000000    0.000000    4.000000   17.000000    6.000000
# 75%      8.000000    2.000000    0.000000    7.000000   30.000000   15.000000
# max     49.000000    5.000000    9.000000   60.000000   96.000000  688.000000
#
#                ca          ce         npm       lcom3  ...         dam  \
# count  135.000000  135.000000  135.000000  135.000000  ...  135.000000
# mean     3.674074    3.451852    4.481481    0.996923  ...    0.121946
# std      8.400275    3.133160    4.710819    0.619312  ...    0.275784
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      0.000000    1.000000    2.000000    0.666667  ...    0.000000
# 50%      1.000000    3.000000    3.000000    0.850000  ...    0.000000
# 75%      3.000000    5.000000    6.500000    1.158333  ...    0.000000
# max     53.000000   15.000000   42.000000    2.000000  ...    1.000000
#
#               moa         mfa         cam          ic         cbm         amc  \
# count  135.000000  135.000000  135.000000  135.000000  135.000000  135.000000
# mean     0.792593    0.293289    0.438925    0.362963    0.711111   20.212411
# std      1.203827    0.393400    0.223166    0.630179    1.510494   17.783473
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.277778    0.000000    0.000000    7.500000
# 50%      0.000000    0.000000    0.375000    0.000000    0.000000   16.428571
# 75%      1.000000    0.679487    0.544444    1.000000    1.000000   27.850000
# max      7.000000    1.000000    1.000000    2.000000   10.000000  100.600000
#
#            max_cc      avg_cc     defects
# count  135.000000  135.000000  135.000000
# mean     3.333333    1.341850    0.451852
# std      3.309868    0.872897    1.104391
# min      0.000000    0.000000    0.000000
# 25%      1.000000    0.800000    0.000000
# 50%      2.000000    1.142900    0.000000
# 75%      4.000000    1.707150    0.500000
# max     23.000000    6.250000    9.000000
#
# [8 rows x 21 columns]

# %%
X= df.iloc[ : , :-1].values
y= df['defects'].apply(lambda x : 1 if(x > 0) else 0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
DecisionTree(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.7037037037037037
# F1 score:  0.6666666666666666
# Auc score:  0.6647727272727273

# %%
SVM(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.5925925925925926
# F1 score:  0.37209302325581395
# Auc score:  0.5

# %%
Logistic(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8888888888888888
# F1 score:  0.8863955119214586
# Auc score:  0.8920454545454545
# C:\Users\AdityaShankar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
Implicit_ME(X_train,y_train,X_test,y_test,6)
# Out:
# Accuracy of Mixture of Experts: 0.8148148148148148
# F1 score 0.8051948051948052
# AUC score 0.8011363636363636

# %%
Explicit_ME(X_train,y_train,X_test,y_test)
# Out:
# Accuracy of Mixture of Experts: 0.8148148148148148
# F1 score 0.8051948051948052
# AUC score 0.8011363636363636

# %%
result = bagging(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.8518518518518519
# F1 score 0.8465909090909092
# AUC score 0.8465909090909092

# %%
result = adaBoost(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.8518518518518519
# F1 score 0.8499999999999999
# AUC score 0.8607954545454546
