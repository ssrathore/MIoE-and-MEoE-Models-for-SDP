# %%
import pandas as pd
from scipy.io import arff
from sklearn.model_selection import train_test_split 
from models import Implicit_ME
from models import Logistic
from models import SVM
from models import DecisionTree
from models import Explicit_ME
from ensemble_models import adaBoost
from ensemble_models import bagging

# %%
data = arff.loadarff('../dataSet/PROMISE/xalan-2.4.arff')

# %%
df = pd.DataFrame(data[0])
df.head()
# Out:
#     wmc  dit   noc   cbo    rfc    lcom    ca    ce   npm     lcom3  ...  \
# 0  16.0  3.0   0.0   6.0   52.0   112.0   1.0   5.0  11.0  0.777778  ...
# 1  12.0  2.0  14.0  23.0   23.0     0.0  17.0   8.0  12.0  0.363636  ...
# 2  53.0  1.0   0.0  34.0  150.0  1362.0  22.0  15.0  49.0  1.001603  ...
# 3  49.0  3.0   2.0  43.0  100.0  1176.0  34.0  12.0  46.0  1.000000  ...
# 4   1.0  1.0   0.0   5.0    1.0     0.0   5.0   1.0   1.0  2.000000  ...
#
#      dam  moa       mfa       cam   ic   cbm        amc  max_cc  avg_cc  \
# 0  1.000  0.0  0.740000  0.344444  2.0   8.0  30.625000     1.0  0.8125
# 1  1.000  2.0  0.731707  0.218750  1.0   7.0  11.250000     5.0  1.5833
# 2  0.375  0.0  0.000000  0.125000  0.0   0.0  37.962264    49.0  4.3962
# 3  0.000  1.0  0.606838  0.122222  3.0  21.0  14.142857    16.0  1.8571
# 4  0.000  0.0  0.000000  1.000000  0.0   0.0   0.000000     1.0  1.0000
#
#    defects
# 0      0.0
# 1      0.0
# 2      1.0
# 3      0.0
# 4      0.0
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#               wmc         dit         noc         cbo         rfc  \
# count  723.000000  723.000000  723.000000  723.000000  723.000000
# mean    11.449516    2.565698    0.608575   14.497925   30.161826
# std     16.295102    1.525240    2.608909   19.343618   35.732309
# min      0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      3.000000    1.000000    0.000000    4.000000    8.000000
# 50%      6.000000    2.000000    0.000000    8.000000   19.000000
# 75%     12.500000    4.000000    0.000000   18.000000   41.000000
# max    123.000000    8.000000   29.000000  171.000000  355.000000
#
#               lcom          ca          ce         npm       lcom3  ...  \
# count   723.000000  723.000000  723.000000  723.000000  723.000000  ...
# mean    130.081604    6.746888    8.460581    9.551867    1.116588  ...
# std     577.039752   16.466312   10.003021   13.925146    0.709978  ...
# min       0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 25%       0.000000    1.000000    1.000000    2.000000    0.545833  ...
# 50%       3.000000    2.000000    5.000000    5.000000    0.881720  ...
# 75%      22.500000    5.000000   12.000000   10.000000    2.000000  ...
# max    6589.000000  155.000000   64.000000  118.000000    2.000000  ...
#
#               dam         moa         mfa         cam          ic         cbm  \
# count  723.000000  723.000000  723.000000  723.000000  723.000000  723.000000
# mean     0.447800    0.907331    0.547803    0.465846    0.919779    3.071923
# std      0.472314    1.873711    0.440130    0.258445    1.085887    4.578987
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.270056    0.000000    0.000000
# 50%      0.051282    0.000000    0.771429    0.400000    1.000000    1.000000
# 75%      1.000000    1.000000    0.960000    0.600000    2.000000    5.000000
# max      1.000000   18.000000    1.000000    1.000000    5.000000   30.000000
#
#               amc      max_cc      avg_cc     defects
# count  723.000000  723.000000  723.000000  723.000000
# mean    26.883182    4.376210    1.346579    0.215768
# std     37.427499    6.473221    1.272702    0.609641
# min      0.000000    0.000000    0.000000    0.000000
# 25%      7.166667    1.000000    0.666700    0.000000
# 50%     16.000000    2.000000    1.000000    0.000000
# 75%     31.174242    6.000000    1.692300    0.000000
# max    436.000000   86.000000   22.000000    7.000000
#
# [8 rows x 21 columns]

# %%
X= df.iloc[ : , :-1].values
y= df['defects'].apply(lambda x : 1 if(x > 0) else 0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
DecisionTree(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8137931034482758
# F1 score:  0.6000612932883849
# Auc score:  0.6023391812865497

# %%
SVM(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8620689655172413
# F1 score:  0.46296296296296297
# Auc score:  0.49603174603174605

# %%
Logistic(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8758620689655172
# F1 score:  0.5911654135338346
# Auc score:  0.5710108604845447
# C:\Users\AdityaShankar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
Implicit_ME(X_train,y_train,X_test,y_test,10)
# Out:
# Accuracy of Mixture of Experts: 0.8689655172413793
# F1 score 0.5841509433962264
# AUC score 0.5670426065162907

# %%
Explicit_ME(X_train,y_train,X_test,y_test)
# Out:
# Accuracy of Mixture of Experts: 0.8758620689655172
# F1 score 0.6197552447552448
# AUC score 0.5933583959899749

# %%
result = bagging(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.8620689655172413
# F1 score 0.5457393483709273
# AUC score 0.5407268170426064

# %%
result = adaBoost(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.8689655172413793
# F1 score 0.5841509433962264
# AUC score 0.5670426065162907
