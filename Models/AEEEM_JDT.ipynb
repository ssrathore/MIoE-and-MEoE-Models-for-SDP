# %%
import pandas as pd
from scipy.io import arff
from sklearn.model_selection import train_test_split 
from models import Implicit_ME
from models import Logistic
from models import SVM
from models import DecisionTree
from models import Explicit_ME
from ensemble_models import adaBoost
from ensemble_models import bagging

# %%
data = arff.loadarff('../dataSet/AEEEM/JDT.arff')

# %%
df = pd.DataFrame(data[0])
df.head()
# Out:
#    ck_oo_numberOfPrivateMethods  LDHH_lcom  LDHH_fanIn  \
# 0                           0.0   0.000934    0.000000
# 1                           0.0   0.000741    0.000000
# 2                           0.0   0.000000    0.000000
# 3                           0.0   0.001529    0.015913
# 4                           0.0   0.000000    0.000000
#
#    numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# 0                                4.0                           0.00
# 1                                3.0                           0.00
# 2                                4.0                           0.00
# 3                               35.0                           0.00
# 4                                2.0                           1.01
#
#    WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# 0                     0.00     0.004517                     0.00000
# 1                     0.00     0.014817                     0.00091
# 2                     1.01     0.024575                     0.00000
# 3                     0.00     0.347495                     0.00165
# 4                     1.01     0.012120                     0.00000
#
#    WCHU_fanIn  LDHH_numberOfPrivateAttributes  ...  LDHH_fanOut  \
# 0        0.00                             0.0  ...     0.000993
# 1        0.00                             0.0  ...     0.000889
# 2        0.00                             0.0  ...     0.002827
# 3        2.03                             0.0  ...     0.010602
# 4        0.00                             0.0  ...     0.005223
#
#    LDHH_numberOfMethodsInherited  LDHH_rfc  ck_oo_numberOfMethodsInherited  \
# 0                       0.025009  0.000969                           127.0
# 1                       0.001487  0.002523                             8.0
# 2                       0.021650  0.003656                            45.0
# 3                       0.012864  0.060975                            94.0
# 4                       0.023725  0.006207                            73.0
#
#    ck_oo_numberOfPublicMethods  LDHH_cbo  WCHU_numberOfLinesOfCode  \
# 0                          4.0  0.001007                      1.03
# 1                          9.0  0.000967                      2.06
# 2                          1.0  0.002917                      1.20
# 3                         21.0  0.027947                     24.14
# 4                          0.0  0.007285                      2.15
#
#    CvsExpEntropy  LDHH_numberOfMethods     class
# 0       0.198199              0.001036  b'clean'
# 1       0.239334              0.000923  b'clean'
# 2       0.187460              0.000000  b'clean'
# 3       0.392389              0.001669  b'buggy'
# 4       0.047726              0.000000  b'clean'
#
# [5 rows x 62 columns]

# %%
df.describe()
# Out:
#        ck_oo_numberOfPrivateMethods   LDHH_lcom  LDHH_fanIn  \
# count                    997.000000  997.000000  997.000000
# mean                       1.297894    0.001777    0.002791
# std                        5.260343    0.004430    0.007316
# min                        0.000000    0.000000    0.000000
# 25%                        0.000000    0.000000    0.000000
# 50%                        0.000000    0.000000    0.000000
# 75%                        1.000000    0.001192    0.001694
# max                      111.000000    0.045838    0.080233
#
#        numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# count                         997.000000                     997.000000
# mean                           10.149448                       0.396409
# std                            19.400677                       1.320920
# min                             0.000000                       0.000000
# 25%                             1.000000                       0.000000
# 50%                             4.000000                       0.000000
# 75%                            10.000000                       0.000000
# max                           200.000000                      15.200000
#
#        WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# count               997.000000   997.000000                  997.000000
# mean                  0.774764     0.053331                    0.001440
# std                   2.317190     0.159108                    0.003932
# min                   0.000000     0.000000                    0.000000
# 25%                   0.000000     0.002877                    0.000000
# 50%                   0.000000     0.007284                    0.000000
# 75%                   1.010000     0.035064                    0.000905
# max                  32.470000     2.285260                    0.043532
#
#        WCHU_fanIn  LDHH_numberOfPrivateAttributes  ...  \
# count  997.000000                      997.000000  ...
# mean     1.125777                        0.000567  ...
# std      2.880374                        0.002544  ...
# min      0.000000                        0.000000  ...
# 25%      0.000000                        0.000000  ...
# 50%      0.000000                        0.000000  ...
# 75%      1.010000                        0.000000  ...
# max     35.570000                        0.037949  ...
#
#        numberOfBugsFoundUntil:  LDHH_fanOut  LDHH_numberOfMethodsInherited  \
# count               997.000000   997.000000                     997.000000
# mean                 11.639920     0.002612                       0.007039
# std                  22.126592     0.005553                       0.009722
# min                   0.000000     0.000000                       0.000000
# 25%                   1.000000     0.000000                       0.001487
# 50%                   5.000000     0.000000                       0.002695
# 75%                  11.000000     0.002669                       0.009737
# max                 214.000000     0.049184                       0.060148
#
#          LDHH_rfc  ck_oo_numberOfMethodsInherited  \
# count  997.000000                      997.000000
# mean     0.006725                       49.236710
# std      0.013519                       50.367666
# min      0.000000                        0.000000
# 25%      0.000000                       11.000000
# 50%      0.001145                       33.000000
# 75%      0.007382                       73.000000
# max      0.127115                      319.000000
#
#        ck_oo_numberOfPublicMethods    LDHH_cbo  WCHU_numberOfLinesOfCode  \
# count                   997.000000  997.000000                997.000000
# mean                      8.952859    0.005242                  4.306800
# std                      19.967363    0.009770                  8.606297
# min                       0.000000    0.000000                  0.000000
# 25%                       3.000000    0.000000                  0.000000
# 50%                       5.000000    0.001056                  1.090000
# 75%                       9.000000    0.006532                  4.350000
# max                     387.000000    0.090432                 91.440000
#
#        CvsExpEntropy  LDHH_numberOfMethods
# count     997.000000            997.000000
# mean        0.120571              0.002304
# std         0.132946              0.005736
# min         0.000000              0.000000
# 25%         0.001125              0.000000
# 50%         0.039072              0.000000
# 75%         0.231202              0.001746
# max         0.580176              0.059817
#
# [8 rows x 61 columns]

# %%
defect_true_false = df.groupby('class')['class'].apply(lambda x: x.count())
print(defect_true_false)
# Out:
# class
# b'buggy'    206
# b'clean'    791
# Name: class, dtype: int64

# %%
df['class'].str.decode("utf-8")
# Out:
# 0      clean
# 1      clean
# 2      clean
# 3      buggy
# 4      clean
#        ...
# 992    clean
# 993    clean
# 994    clean
# 995    clean
# 996    clean
# Name: class, Length: 997, dtype: object

# %%
X= df.iloc[ : , :-1].values
y= df['class'].str.decode("utf-8").map({'buggy': 1, 'clean': 0})

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
DecisionTree(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.82
# F1 score:  0.7333728336542735
# Auc score:  0.7521898391463608

# %%
SVM(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.835
# F1 score:  0.6411288130063617
# Auc score:  0.615782767956681

# %%
Logistic(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.84
# F1 score:  0.7165131112686038
# Auc score:  0.696607740086001
# C:\Users\AdityaShankar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
Implicit_ME(X_train,y_train,X_test,y_test,10)
# Out:
# Accuracy of Mixture of Experts: 0.86
# F1 score 0.7519489723600283
# AUC score 0.7284599458512502

# %%
Explicit_ME(X_train,y_train,X_test,y_test)
# Out:
# Accuracy of Mixture of Experts: 0.865
# F1 score 0.7579669221460266
# AUC score 0.731565535913362

# %%
result = bagging(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.805
# F1 score 0.6863817297253829
# AUC score 0.6845835324096193

# %%
result = adaBoost(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.84
# F1 score 0.7347040291825568
# AUC score 0.725752508361204
