# %%
import pandas as pd
from scipy.io import arff
from sklearn.model_selection import train_test_split 
from models import Implicit_ME
from models import Logistic
from models import SVM
from models import DecisionTree
from models import Explicit_ME
from ensemble_models import adaBoost
from ensemble_models import bagging

# %%
data = arff.loadarff('../dataSet/PROMISE/xerces-1.3.arff')

# %%
df = pd.DataFrame(data[0])
df.head()
# Out:
#     wmc  dit  noc   cbo   rfc   lcom    ca    ce   npm     lcom3  ...  dam  \
# 0  34.0  2.0  0.0  14.0  74.0    0.0   1.0  14.0  21.0  0.672727  ...  1.0
# 1  46.0  1.0  0.0  13.0  61.0  833.0  11.0   2.0  46.0  0.903704  ...  1.0
# 2   4.0  1.0  0.0   0.0   4.0    6.0   0.0   0.0   4.0  2.000000  ...  0.0
# 3   4.0  1.0  0.0   0.0   4.0    6.0   0.0   0.0   4.0  2.000000  ...  0.0
# 4  41.0  2.0  0.0  11.0  75.0  280.0   2.0   9.0  35.0  0.903947  ...  1.0
#
#     moa       mfa       cam   ic  cbm        amc  max_cc  avg_cc  defects
# 0   2.0  0.179487  0.160839  1.0  3.0  83.558824     2.0  1.0588      0.0
# 1   1.0  0.000000  0.220497  0.0  0.0  11.195652    12.0  1.6522      0.0
# 2   0.0  0.000000  0.750000  0.0  0.0   0.000000     1.0  1.0000      0.0
# 3   0.0  0.000000  0.500000  0.0  0.0   0.000000     1.0  1.0000      0.0
# 4  10.0  0.487179  0.306620  1.0  7.0  28.414634     3.0  1.1951      0.0
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#               wmc         dit         noc         cbo         rfc  \
# count  453.000000  453.000000  453.000000  453.000000  453.000000
# mean    11.377483    2.008830    0.454746    5.075055   21.704194
# std     13.348333    1.276025    3.139219    8.389238   32.462993
# min      0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      3.000000    1.000000    0.000000    0.000000    5.000000
# 50%      7.000000    1.000000    0.000000    2.000000   12.000000
# 75%     14.000000    3.000000    0.000000    6.000000   24.000000
# max     95.000000    5.000000   52.000000   60.000000  297.000000
#
#               lcom          ca          ce         npm       lcom3  ...  \
# count   453.000000  453.000000  453.000000  453.000000  453.000000  ...
# mean     94.523179    2.666667    2.754967    8.814570    1.465238  ...
# std     250.156654    6.838314    4.740104    9.203504    0.657025  ...
# min       0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 25%       1.000000    0.000000    0.000000    2.000000    0.833333  ...
# 50%      10.000000    1.000000    2.000000    6.000000    2.000000  ...
# 75%      55.000000    2.000000    3.000000   11.000000    2.000000  ...
# max    2425.000000   57.000000   55.000000   55.000000    2.000000  ...
#
#               dam         moa         mfa         cam          ic         cbm  \
# count  453.000000  453.000000  453.000000  453.000000  453.000000  453.000000
# mean     0.264632    0.803532    0.357340    0.503663    0.346578    1.375276
# std      0.409421    2.803093    0.424897    0.240612    0.659490    3.088017
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.333333    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.500000    0.000000    0.000000
# 75%      0.600000    0.000000    0.870370    0.666667    1.000000    1.000000
# max      1.000000   41.000000    1.000000    1.000000    4.000000   25.000000
#
#               amc      max_cc      avg_cc     defects
# count  453.000000  453.000000  453.000000  453.000000
# mean    21.964005    3.452539    1.236002    0.426049
# std     58.898383    8.770454    1.180637    1.899448
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000    0.833300    0.000000
# 50%      4.666667    1.000000    1.000000    0.000000
# 75%     21.100000    3.000000    1.130400    0.000000
# max    779.800000  147.000000   13.358500   30.000000
#
# [8 rows x 21 columns]

# %%
X= df.iloc[ : , :-1].values
y= df['defects'].apply(lambda x : 1 if(x > 0) else 0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
DecisionTree(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8241758241758241
# F1 score:  0.6966666666666665
# Auc score:  0.6879968203497616

# %%
SVM(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8021978021978022
# F1 score:  0.4451219512195122
# Auc score:  0.49324324324324326

# %%
Logistic(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8241758241758241
# F1 score:  0.6623376623376623
# Auc score:  0.6426868044515104
# C:\Users\AdityaShankar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
Implicit_ME(X_train,y_train,X_test,y_test,10)
# Out:
# Accuracy of Mixture of Experts: 0.8241758241758241
# F1 score 0.5863636363636364
# AUC score 0.5747217806041336

# %%
Explicit_ME(X_train,y_train,X_test,y_test)
# Out:
# Accuracy of Mixture of Experts: 0.8241758241758241
# F1 score 0.5863636363636364
# AUC score 0.5747217806041336

# %%
result = bagging(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.8461538461538461
# F1 score 0.6640295358649789
# AUC score 0.6335453100158983

# %%
result = adaBoost(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.8571428571428571
# F1 score 0.676510801203172
# AUC score 0.6403020667726551
