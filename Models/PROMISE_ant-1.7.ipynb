# %%
import pandas as pd
from scipy.io import arff
from sklearn.model_selection import train_test_split 
from models import Implicit_ME
from models import Logistic
from models import SVM
from models import Explicit_ME
from models import DecisionTree
from ensemble_models import adaBoost
from ensemble_models import bagging

# %%
data = arff.loadarff('../dataSet/PROMISE/ant-1.7.arff')

# %%
df = pd.DataFrame(data[0])
df.head()
# Out:
#    wmc  dit  noc   cbo   rfc  lcom   ca   ce  npm  lcom3  ...  dam  moa  mfa  \
# 0  3.0  1.0  0.0  10.0  18.0   3.0  1.0  9.0  1.0  1.100  ...  0.0  0.0  0.0
# 1  5.0  2.0  0.0   4.0  13.0   0.0  1.0  4.0  4.0  0.625  ...  1.0  1.0  0.7
# 2  1.0  2.0  0.0   1.0   3.0   0.0  0.0  1.0  1.0  2.000  ...  0.0  0.0  1.0
# 3  8.0  1.0  9.0  13.0  20.0  12.0  9.0  4.0  8.0  0.800  ...  0.2  1.0  0.0
# 4  9.0  3.0  0.0   5.0  26.0  16.0  0.0  5.0  7.0  0.750  ...  1.0  0.0  0.8
#
#         cam   ic  cbm        amc  max_cc  avg_cc  defects
# 0  0.444444  0.0  0.0  32.666667     1.0  0.6667      0.0
# 1  0.500000  0.0  0.0  13.400000     1.0  0.6000      0.0
# 2  1.000000  0.0  0.0   6.000000     0.0  0.0000      0.0
# 3  0.406250  0.0  0.0  11.000000     1.0  0.8750      0.0
# 4  0.388889  0.0  0.0  19.000000     2.0  1.0000      1.0
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#               wmc         dit         noc         cbo         rfc  \
# count  745.000000  745.000000  745.000000  745.000000  745.000000
# mean    11.071141    2.522148    0.731544   11.046980   34.362416
# std     11.975963    1.398869    4.800357   26.343149   36.024972
# min      0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      4.000000    1.000000    0.000000    4.000000   11.000000
# 50%      7.000000    2.000000    0.000000    6.000000   23.000000
# 75%     14.000000    4.000000    0.000000   11.000000   43.000000
# max    120.000000    7.000000  102.000000  499.000000  288.000000
#
#               lcom          ca          ce         npm       lcom3  ...  \
# count   745.000000  745.000000  745.000000  745.000000  745.000000  ...
# mean     89.147651    5.655034    5.746309    8.365101    1.013342  ...
# std     349.937555   25.814223    5.653176    9.331319    0.619015  ...
# min       0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 25%       0.000000    0.000000    2.000000    3.000000    0.666667  ...
# 50%       6.000000    1.000000    4.000000    6.000000    0.833333  ...
# 75%      53.000000    4.000000    8.000000   10.000000    1.500000  ...
# max    6692.000000  498.000000   37.000000  103.000000    2.000000  ...
#
#               dam         moa         mfa         cam          ic         cbm  \
# count  745.000000  745.000000  745.000000  745.000000  745.000000  745.000000
# mean     0.644855    0.726174    0.509968    0.474685    0.720805    1.312752
# std      0.438138    1.426581    0.398696    0.259931    0.938948    2.332602
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.269841    0.000000    0.000000
# 50%      1.000000    0.000000    0.681818    0.437500    0.000000    0.000000
# 75%      1.000000    1.000000    0.869919    0.666667    1.000000    2.000000
# max      1.000000   11.000000    1.000000    1.000000    5.000000   19.000000
#
#                amc      max_cc      avg_cc     defects
# count   745.000000  745.000000  745.000000  745.000000
# mean     23.640870    4.669799    1.366053    0.453691
# std      76.986079    6.276853    0.881739    1.138673
# min       0.000000    0.000000    0.000000    0.000000
# 25%       9.066667    1.000000    0.857100    0.000000
# 50%      16.400000    3.000000    1.142900    0.000000
# 75%      28.000000    6.000000    1.666700    0.000000
# max    2052.000000   53.000000    6.777800   10.000000
#
# [8 rows x 21 columns]

# %%
X= df.iloc[ : , :-1].values
y= df['defects'].apply(lambda x : 1 if(x > 0) else 0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
DecisionTree(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.7516778523489933
# F1 score:  0.6643531202435311
# Auc score:  0.6602655286865813

# %%
SVM(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8120805369127517
# F1 score:  0.700287356321839
# Auc score:  0.6748458985301091

# %%
Logistic(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8053691275167785
# F1 score:  0.6854480599839848
# Auc score:  0.661688003793267
# C:\Users\AdityaShankar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
Implicit_ME(X_train,y_train,X_test,y_test,10)
# Out:
# Accuracy of Mixture of Experts: 0.785234899328859
# F1 score 0.6481700118063755
# AUC score 0.6308677098150783

# %%
Explicit_ME(X_train,y_train,X_test,y_test)
# Out:
# Accuracy of Mixture of Experts: 0.7986577181208053
# F1 score 0.6788793103448276
# AUC score 0.6571834992887624

# %%
result = bagging(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.7919463087248322
# F1 score 0.6333253949353019
# AUC score 0.6180654338549075

# %%
result = adaBoost(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.8389261744966443
# F1 score 0.7759398496240602
# AUC score 0.7620910384068278
