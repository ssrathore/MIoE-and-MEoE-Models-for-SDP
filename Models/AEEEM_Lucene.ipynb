# %%
import pandas as pd
from scipy.io import arff
from sklearn.model_selection import train_test_split 
from models import Implicit_ME
from models import Logistic
from models import SVM
from models import DecisionTree
from models import Explicit_ME
from ensemble_models import adaBoost
from ensemble_models import bagging

# %%
data = arff.loadarff('../dataSet/AEEEM/Lucene.arff')

# %%
df = pd.DataFrame(data[0])
df.head()
# Out:
#    ck_oo_numberOfPrivateMethods  LDHH_lcom  LDHH_fanIn  \
# 0                           0.0   0.000000     0.01525
# 1                           0.0   0.000000     0.00000
# 2                           7.0   0.002984     0.00000
# 3                          12.0   0.000000     0.00000
# 4                           0.0   0.000000     0.00000
#
#    numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# 0                                2.0                            0.0
# 1                                1.0                            0.0
# 2                                4.0                            0.0
# 3                                1.0                            0.0
# 4                                1.0                            0.0
#
#    WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# 0                     0.00     0.033871                    0.002200
# 1                     0.00     0.000518                    0.000000
# ...

# %%
df.describe()
# Out:
#        ck_oo_numberOfPrivateMethods   LDHH_lcom  LDHH_fanIn  \
# count                    691.000000  691.000000  691.000000
# mean                       1.327062    0.002367    0.007577
# std                        4.301345    0.006803    0.019344
# min                        0.000000    0.000000    0.000000
# 25%                        0.000000    0.000000    0.000000
# 50%                        0.000000    0.000000    0.000000
# 75%                        1.000000    0.001062    0.002874
# max                       47.000000    0.061262    0.153580
#
#        numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# count                         691.000000                     691.000000
# mean                            2.480463                       0.130087
# std                             4.958156                       0.540472
# min                             0.000000                       0.000000
# ...

# %%
defect_true_false = df.groupby('class')['class'].apply(lambda x: x.count())
print(defect_true_false)
# Out:
# class
# b'buggy'     64
# b'clean'    627
# Name: class, dtype: int64

# %%
df['class'].str.decode("utf-8")
# Out:
# 0      clean
# 1      clean
# 2      clean
# 3      clean
# 4      clean
#        ...
# 686    buggy
# 687    clean
# 688    clean
# 689    clean
# 690    clean
# Name: class, Length: 691, dtype: object

# %%
X= df.iloc[ : , :-1].values
y= df['class'].str.decode("utf-8").map({'buggy': 1, 'clean': 0})

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
DecisionTree(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8992805755395683
# F1 score:  0.5841880341880342
# Auc score:  0.6290726817042607

# %%
SVM(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.9568345323741008
# F1 score:  0.48897058823529416
# Auc score:  0.5

# %%
Logistic(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.935251798561151
# F1 score:  0.6368650217706822
# Auc score:  0.6478696741854636
# C:\Users\AdityaShankar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
Implicit_ME(X_train,y_train,X_test,y_test,10)
# Out:
# Accuracy of Mixture of Experts: 0.9496402877697842
# F1 score 0.668709567585972
# AUC score 0.6553884711779449

# %%
Explicit_ME(X_train,y_train,X_test,y_test)
# Out:
# Accuracy of Mixture of Experts: 0.9568345323741008
# F1 score 0.6888059701492537
# AUC score 0.6591478696741855

# %%
result = bagging(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.9280575539568345
# F1 score 0.6239177489177489
# AUC score 0.644110275689223

# %%
result = adaBoost(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.935251798561151
# F1 score 0.6368650217706822
# AUC score 0.6478696741854636
