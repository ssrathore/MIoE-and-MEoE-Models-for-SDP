# %%
import pandas as pd
from scipy.io import arff
from sklearn.model_selection import train_test_split 
from models import Implicit_ME
from models import Logistic
from models import SVM
from models import DecisionTree
from models import Explicit_ME
from ensemble_models import adaBoost
from ensemble_models import bagging

# %%
data = arff.loadarff('../dataSet/PROMISE/jedit-4.0.arff')

# %%
df = pd.DataFrame(data[0])
df.head()
# Out:
#     wmc  dit  noc   cbo    rfc  lcom   ca    ce  npm     lcom3  ...  dam  moa  \
# 0   6.0  8.0  0.0  10.0   22.0  15.0  1.0  10.0  4.0  2.000000  ...  0.0  0.0
# 1  12.0  6.0  0.0   7.0   39.0  28.0  3.0   6.0  1.0  0.397727  ...  1.0  2.0
# 2  14.0  7.0  0.0  28.0  108.0  69.0  3.0  28.0  8.0  0.869231  ...  1.0  2.0
# 3   2.0  2.0  0.0   2.0    6.0   1.0  1.0   2.0  2.0  2.000000  ...  0.0  0.0
# 4   5.0  6.0  0.0   5.0   28.0   0.0  2.0   4.0  1.0  0.708333  ...  1.0  0.0
#
#         mfa       cam   ic  cbm        amc  max_cc  avg_cc  defects
# 0  0.994206  0.333333  1.0  7.0  20.333333     5.0  2.1667      0.0
# 1  0.983655  0.500000  1.0  3.0  45.416667     2.0  1.1667      1.0
# 2  0.980480  0.174603  0.0  0.0  50.571429     9.0  2.1429      2.0
# 3  0.875000  0.625000  0.0  0.0  41.500000     5.0  2.5000      0.0
# 4  0.993994  0.500000  2.0  4.0  64.000000     3.0  1.6000      1.0
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#               wmc         dit         noc         cbo         rfc  \
# count  306.000000  306.000000  306.000000  306.000000  306.000000
# mean    12.882353    2.764706    0.441176   12.395425   38.241830
# std     30.958341    2.118659    2.698780   18.040860   57.019183
# min      1.000000    1.000000    0.000000    1.000000    1.000000
# 25%      3.000000    1.000000    0.000000    4.000000    9.000000
# 50%      6.000000    2.000000    0.000000    7.000000   22.000000
# 75%     12.000000    4.000000    0.000000   12.750000   41.000000
# max    407.000000    8.000000   35.000000  184.000000  494.000000
#
#                lcom          ca          ce         npm       lcom3  ...  \
# count    306.000000  306.000000  306.000000  306.000000  306.000000  ...
# mean     197.375817    7.513072    6.428105    7.702614    1.045607  ...
# std     1221.246144   15.768660    7.626726   16.295221    0.601964  ...
# min        0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 25%        1.000000    1.000000    2.000000    1.000000    0.654447  ...
# 50%        4.000000    3.000000    4.000000    3.000000    0.833333  ...
# 75%       28.000000    7.000000    8.000000    8.000000    2.000000  ...
# max    16336.000000  157.000000   59.000000  193.000000    2.000000  ...
#
#               dam         moa         mfa         cam          ic         cbm  \
# count  306.000000  306.000000  306.000000  306.000000  306.000000  306.000000
# mean     0.558850    0.934641    0.535315    0.471059    0.673203    1.614379
# std      0.464729    1.915162    0.443495    0.249234    0.990645    3.230235
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.286161    0.000000    0.000000
# 50%      0.800000    0.000000    0.737108    0.436667    0.000000    0.000000
# 75%      1.000000    1.000000    0.973174    0.625000    1.000000    2.000000
# max      1.000000   17.000000    1.000000    1.000000    4.000000   25.000000
#
#               amc      max_cc      avg_cc     defects
# count  306.000000  306.000000  306.000000  306.000000
# mean    31.341902    6.225490    1.791688    0.738562
# std     37.219498    9.433015    1.797512    2.356077
# min      0.000000    0.000000    0.000000    0.000000
# 25%     11.409091    1.000000    0.808325    0.000000
# 50%     24.041667    3.000000    1.348450    0.000000
# 75%     41.475000    8.000000    2.250000    0.000000
# max    496.000000   84.000000   20.000000   23.000000
#
# [8 rows x 21 columns]

# %%
X= df.iloc[ : , :-1].values
y= df['defects'].apply(lambda x : 1 if(x > 0) else 0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
DecisionTree(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.7741935483870968
# F1 score:  0.6921985815602837
# Auc score:  0.7023809523809523

# %%
SVM(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8064516129032258
# F1 score:  0.610062893081761
# Auc score:  0.5967261904761905

# %%
Logistic(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.7741935483870968
# F1 score:  0.6383333333333333
# Auc score:  0.6264880952380952
# C:\Users\AdityaShankar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
Implicit_ME(X_train,y_train,X_test,y_test,10)
# Out:
# Accuracy of Mixture of Experts: 0.8225806451612904
# F1 score 0.7244444444444444
# AUC score 0.7083333333333334

# %%
Explicit_ME(X_train,y_train,X_test,y_test)
# Out:
# Accuracy of Mixture of Experts: 0.8387096774193549
# F1 score 0.7566718995290423
# AUC score 0.7440476190476191

# %%
result = bagging(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.8225806451612904
# F1 score 0.7524500907441016
# AUC score 0.7589285714285714

# %%
result = adaBoost(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.8387096774193549
# F1 score 0.7693452380952381
# AUC score 0.7693452380952381
