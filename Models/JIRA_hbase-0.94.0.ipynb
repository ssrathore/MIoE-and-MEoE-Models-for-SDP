# %%
import pandas as pd
from scipy.io import arff
from sklearn.model_selection import train_test_split 
from models import Implicit_ME
from models import Logistic
from models import SVM
from models import DecisionTree
from models import Explicit_ME
from ensemble_models import adaBoost
from ensemble_models import bagging

# %%
data = arff.loadarff('../dataSet/JIRA/hbase-0.94.0.arff')

# %%
df = pd.DataFrame(data[0])
df.head()
# Out:
#    CountDeclMethodPrivate  AvgLineCode  CountLine  MaxCyclomatic  \
# 0                     6.0         21.0      487.0           12.0
# 1                     0.0          8.0      118.0            6.0
# 2                     2.0         12.0      412.0           10.0
# 3                     9.0         18.0      737.0           21.0
# 4                     0.0          4.0       84.0            2.0
#
#    CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# 0                     0.0           1.0                     2.0
# 1                     0.0           1.0                     0.0
# 2                     0.0           1.0                     2.0
# 3                     3.0           2.0                     8.0
# 4                     2.0           1.0                     0.0
#
#    SumCyclomaticStrict  AvgCyclomatic  AvgLine  ...  DDEV  Added_lines  \
# 0                 69.0            4.0     27.0  ...   1.0         34.0
# 1                 15.0            2.0     10.0  ...   1.0          0.0
# 2                 46.0            2.0     16.0  ...   1.0         45.0
# 3                122.0            4.0     20.0  ...   2.0         38.0
# 4                  6.0            1.0      5.0  ...   1.0          0.0
#
#    Del_lines  OWN_LINE  OWN_COMMIT  MINOR_COMMIT  MINOR_LINE  MAJOR_COMMIT  \
# 0      522.0    1.0000         1.0           0.0         1.0           1.0
# 1      118.0    1.0000         1.0           0.0         1.0           1.0
# 2      458.0    1.0000         1.0           0.0         1.0           1.0
# 3      766.0    0.9729         0.8           0.0         1.0           2.0
# 4       84.0    1.0000         1.0           0.0         1.0           1.0
#
#    MAJOR_LINE  RealBugCount
# 0         0.0           1.0
# 1         0.0           0.0
# 2         0.0           0.0
# 3         2.0           0.0
# 4         0.0           0.0
#
# [5 rows x 66 columns]

# %%
df.describe()
# Out:
#        CountDeclMethodPrivate  AvgLineCode     CountLine  MaxCyclomatic  \
# count             1059.000000  1059.000000   1059.000000    1059.000000
# mean                 2.033050     9.889518    349.759207       5.103872
# std                  6.675566     8.904666   1681.588278       5.187284
# min                  0.000000     0.000000      0.000000       0.000000
# 25%                  0.000000     4.000000     81.000000       1.000000
# 50%                  0.000000     8.000000    157.000000       3.000000
# 75%                  2.000000    13.000000    320.500000       7.000000
# max                165.000000    97.000000  51285.000000      45.000000
#
#        CountDeclMethodDefault  AvgEssential  CountDeclClassVariable  \
# count             1059.000000   1059.000000             1059.000000
# mean                 1.401322      1.159585                3.653447
# std                  5.301892      0.548266               19.089477
# min                  0.000000      0.000000                0.000000
# 25%                  0.000000      1.000000                0.000000
# 50%                  0.000000      1.000000                1.000000
# 75%                  1.000000      1.000000                3.000000
# max                 82.000000      8.000000              560.000000
#
#        SumCyclomaticStrict  AvgCyclomatic      AvgLine  ...         DDEV  \
# count          1059.000000    1059.000000  1059.000000  ...  1059.000000
# mean             45.881964       1.934844    13.507082  ...     1.816808
# std             354.017542       1.318225    11.642789  ...     1.308132
# min               0.000000       0.000000     0.000000  ...     0.000000
# 25%               5.000000       1.000000     6.000000  ...     1.000000
# 50%              14.000000       2.000000    11.000000  ...     1.000000
# 75%              34.000000       2.000000    18.000000  ...     2.000000
# max           10982.000000      13.000000   137.000000  ...     9.000000
#
#         Added_lines     Del_lines     OWN_LINE   OWN_COMMIT  MINOR_COMMIT  \
# count   1059.000000   1059.000000  1059.000000  1059.000000   1059.000000
# mean     150.637394     70.630784     0.836778     0.715978      0.041549
# std     1307.650490    645.434992     0.191163     0.303751      0.374231
# min        0.000000      0.000000     0.000000     0.000000      0.000000
# 25%        4.000000      0.000000     0.716092     0.500000      0.000000
# 50%       11.000000      1.000000     0.928000     0.714286      0.000000
# 75%       91.000000     20.000000     1.000000     1.000000      0.000000
# max    41581.000000  20224.000000     1.000000     1.000000      5.000000
#
#         MINOR_LINE  MAJOR_COMMIT   MAJOR_LINE  RealBugCount
# count  1059.000000   1059.000000  1059.000000   1059.000000
# mean      1.864967      1.775260     1.130312      0.749764
# std       1.124437      1.178137     1.560384      2.387880
# min       0.000000      0.000000     0.000000      0.000000
# 25%       1.000000      1.000000     0.000000      0.000000
# 50%       2.000000      1.000000     1.000000      0.000000
# 75%       2.000000      2.000000     2.000000      0.000000
# max       9.000000      7.000000    11.000000     37.000000
#
# [8 rows x 66 columns]

# %%
X= df.iloc[ : , :-1].values
y= df['RealBugCount'].apply(lambda x : 1 if(x > 0) else 0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
DecisionTree(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8018867924528302
# F1 score:  0.6882352941176471
# Auc score:  0.6749194068343004

# %%
SVM(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.7783018867924528
# F1 score:  0.43766578249336874
# Auc score:  0.5

# %%
Logistic(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.7594339622641509
# F1 score:  0.5686071100825919
# Auc score:  0.5639587362991619
# C:\Users\AdityaShankar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
Implicit_ME(X_train,y_train,X_test,y_test,10)
# Out:
# Accuracy of Mixture of Experts: 0.8490566037735849
# F1 score 0.7323232323232325
# AUC score 0.6976144422952933

# %%
Explicit_ME(X_train,y_train,X_test,y_test)
# Out:
# Accuracy of Mixture of Experts: 0.8207547169811321
# F1 score 0.6889575289575289
# AUC score 0.6642166344294003

# %%
result = bagging(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.8490566037735849
# F1 score 0.7434966727162734
# AUC score 0.7128304319793681

# %%
result = adaBoost(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.839622641509434
# F1 score 0.7562229437229437
# AUC score 0.7448098001289492
