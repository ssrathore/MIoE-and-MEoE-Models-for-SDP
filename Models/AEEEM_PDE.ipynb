# %%
import pandas as pd
from scipy.io import arff
from sklearn.model_selection import train_test_split 
from models import Implicit_ME
from models import Logistic
from models import SVM
from models import DecisionTree
from models import Explicit_ME
from ensemble_models import adaBoost
from ensemble_models import bagging

# %%
data = arff.loadarff('../dataSet/AEEEM/PDE.arff')

# %%
df = pd.DataFrame(data[0])
df.head()
# Out:
#    ck_oo_numberOfPrivateMethods  LDHH_lcom  LDHH_fanIn  \
# 0                           0.0   0.003976    0.005189
# 1                           0.0   0.000000    0.000000
# 2                           8.0   0.002264    0.000000
# 3                           2.0   0.000000    0.001689
# 4                           1.0   0.005692    0.007865
#
#    numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# 0                                2.0                            0.0
# 1                                0.0                            0.0
# 2                                7.0                            0.0
# 3                                3.0                            0.0
# 4                                3.0                            0.0
#
#    WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# 0                     3.03     0.105389                    0.004203
# 1                     0.00     0.000000                    0.000000
# 2                     0.00     0.032927                    0.000000
# 3                     0.00     0.061022                    0.000000
# 4                     6.14     0.109004                    0.001720
#
#    WCHU_fanIn  LDHH_numberOfPrivateAttributes  ...  LDHH_fanOut  \
# 0        2.04                        0.004297  ...     0.010649
# 1        0.00                        0.000000  ...     0.000000
# 2        0.00                        0.000000  ...     0.002006
# 3        2.06                        0.000000  ...     0.001873
# 4        5.09                        0.004365  ...     0.002715
#
#    LDHH_numberOfMethodsInherited  LDHH_rfc  ck_oo_numberOfMethodsInherited  \
# 0                       0.002227  0.027707                            14.0
# 1                       0.000000  0.000000                            51.0
# 2                       0.000713  0.004680                            14.0
# 3                       0.000000  0.005933                             0.0
# 4                       0.000000  0.007782                             0.0
#
#    ck_oo_numberOfPublicMethods  LDHH_cbo  WCHU_numberOfLinesOfCode  \
# 0                          6.0  0.008929                      4.28
# 1                          3.0  0.000000                      0.00
# 2                          2.0  0.001619                      5.44
# 3                          6.0  0.003134                      6.39
# 4                         18.0  0.007727                      8.66
#
#    CvsExpEntropy  LDHH_numberOfMethods     class
# 0       0.209245              0.004770  b'clean'
# 1       0.000000              0.000000  b'clean'
# 2       0.054240              0.002453  b'clean'
# 3       0.046823              0.000000  b'buggy'
# 4       0.051960              0.006210  b'clean'
#
# [5 rows x 62 columns]

# %%
df.describe()
# Out:
#        ck_oo_numberOfPrivateMethods    LDHH_lcom   LDHH_fanIn  \
# count                   1497.000000  1497.000000  1497.000000
# mean                       2.245825     0.001574     0.001975
# std                        4.697361     0.002862     0.005812
# min                        0.000000     0.000000     0.000000
# 25%                        0.000000     0.000000     0.000000
# 50%                        0.000000     0.000000     0.000000
# 75%                        2.000000     0.001992     0.001443
# max                       52.000000     0.023066     0.085575
#
#        numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# count                        1497.000000                    1497.000000
# mean                            2.799599                       0.117756
# std                             5.506552                       2.647486
# min                             0.000000                       0.000000
# 25%                             0.000000                       0.000000
# 50%                             1.000000                       0.000000
# 75%                             3.000000                       0.000000
# max                           143.000000                      94.180000
#
#        WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# count              1497.000000  1497.000000                 1497.000000
# mean                  0.760474     0.041631                    0.000811
# std                   3.019108     0.074545                    0.001761
# min                   0.000000     0.000000                    0.000000
# 25%                   0.000000     0.003847                    0.000000
# 50%                   0.000000     0.013742                    0.000000
# 75%                   1.010000     0.043105                    0.000909
# max                  94.180000     0.782287                    0.021797
#
#         WCHU_fanIn  LDHH_numberOfPrivateAttributes  ...  \
# count  1497.000000                     1497.000000  ...
# mean      1.281964                        0.000800  ...
# std       3.778914                        0.002328  ...
# min       0.000000                        0.000000  ...
# 25%       0.000000                        0.000000  ...
# 50%       0.000000                        0.000000  ...
# 75%       1.010000                        0.000757  ...
# max      62.580000                        0.029220  ...
#
#        numberOfBugsFoundUntil:  LDHH_fanOut  LDHH_numberOfMethodsInherited  \
# count               1497.00000  1497.000000                    1497.000000
# mean                   3.87642     0.002323                       0.002848
# std                    7.88572     0.003963                       0.004036
# min                    0.00000     0.000000                       0.000000
# 25%                    1.00000     0.000000                       0.000000
# 50%                    2.00000     0.000687                       0.001646
# 75%                    4.00000     0.003032                       0.004021
# max                  232.00000     0.031046                       0.020870
#
#           LDHH_rfc  ck_oo_numberOfMethodsInherited  \
# count  1497.000000                     1497.000000
# mean      0.003629                       28.627923
# std       0.006261                       55.840023
# min       0.000000                        0.000000
# 25%       0.000000                        6.000000
# 50%       0.001423                       10.000000
# 75%       0.004623                       30.000000
# max       0.067824                      602.000000
#
#        ck_oo_numberOfPublicMethods     LDHH_cbo  WCHU_numberOfLinesOfCode  \
# count                  1497.000000  1497.000000               1497.000000
# mean                      5.577822     0.004181                  3.248824
# std                       5.421855     0.007395                  4.571278
# min                       0.000000     0.000000                  0.000000
# 25%                       2.000000     0.000000                  0.000000
# 50%                       4.000000     0.001643                  2.030000
# 75%                       8.000000     0.005045                  4.210000
# max                      53.000000     0.090029                 34.770000
#
#        CvsExpEntropy  LDHH_numberOfMethods
# count    1497.000000           1497.000000
# mean        0.055466              0.001747
# std         0.046783              0.003245
# min         0.000000              0.000000
# 25%         0.034241              0.000000
# 50%         0.041955              0.000000
# 75%         0.056580              0.002222
# max         0.595488              0.035209
#
# [8 rows x 61 columns]

# %%
defect_true_false = df.groupby('class')['class'].apply(lambda x: x.count())
print(defect_true_false)
# Out:
# class
# b'buggy'     209
# b'clean'    1288
# Name: class, dtype: int64

# %%
df['class'].str.decode("utf-8")
# Out:
# 0       clean
# 1       clean
# 2       clean
# 3       buggy
# 4       clean
#         ...
# 1492    buggy
# 1493    clean
# 1494    clean
# 1495    clean
# 1496    buggy
# Name: class, Length: 1497, dtype: object

# %%
X= df.iloc[ : , :-1].values
y= df['class'].str.decode("utf-8").map({'buggy': 1, 'clean': 0})

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
DecisionTree(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.85
# F1 score:  0.6117900790797988
# Auc score:  0.6103166496424923

# %%
SVM(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.89
# F1 score:  0.4708994708994709
# Auc score:  0.5

# %%
Logistic(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8866666666666667
# F1 score:  0.5647721454173067
# Auc score:  0.5512427647259107
# C:\Users\AdityaShankar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
Implicit_ME(X_train,y_train,X_test,y_test,10)
# Out:
# Accuracy of Mixture of Experts: 0.88
# F1 score 0.5762046774446712
# AUC score 0.5607763023493362

# %%
Explicit_ME(X_train,y_train,X_test,y_test)
# Out:
# Accuracy of Mixture of Experts: 0.8866666666666667
# F1 score 0.5830608240680183
# AUC score 0.564521620701396

# %%
result = bagging(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.88
# F1 score 0.5585349901896665
# AUC score 0.5474974463738509

# %%
result = adaBoost(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.8733333333333333
# F1 score 0.6133496133496134
# AUC score 0.5968675519237318
