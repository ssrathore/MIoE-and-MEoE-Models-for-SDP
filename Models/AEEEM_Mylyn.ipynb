# %%
import pandas as pd
from scipy.io import arff
from sklearn.model_selection import train_test_split 
from models import Implicit_ME
from models import Logistic
from models import SVM
from models import DecisionTree
from models import Explicit_ME
from ensemble_models import adaBoost
from ensemble_models import bagging

# %%
data = arff.loadarff('../dataSet/AEEEM/Mylyn.arff')

# %%
df = pd.DataFrame(data[0])
df.head()
# Out:
#    ck_oo_numberOfPrivateMethods  LDHH_lcom  LDHH_fanIn  \
# 0                           1.0   0.019228    0.024845
# 1                           0.0   0.000000    0.000000
# 2                           1.0   0.000000    0.000000
# 3                           0.0   0.000734    0.056522
# 4                           0.0   0.000000    0.010560
#
#    numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# 0                                4.0                            0.0
# 1                               20.0                            0.0
# 2                                0.0                            0.0
# 3                                6.0                            0.0
# 4                                5.0                            0.0
#
#    WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# 0                     1.01     0.002216                    0.018552
# 1                     0.00     0.278898                    0.000000
# 2                     0.00     0.000000                    0.000000
# 3                     1.01     0.013173                    0.001171
# 4                     0.00     0.042989                    0.000000
#
#    WCHU_fanIn  LDHH_numberOfPrivateAttributes  ...  LDHH_fanOut  \
# 0        1.02                        0.017874  ...     0.000000
# 1        0.00                        0.000000  ...     0.013098
# 2        0.00                        0.000000  ...     0.000000
# 3        8.10                        0.001505  ...     0.000000
# 4        5.11                        0.000000  ...     0.022584
#
#    LDHH_numberOfMethodsInherited  LDHH_rfc  ck_oo_numberOfMethodsInherited  \
# 0                       0.002801  0.020688                            36.0
# 1                       0.009791  0.006229                             9.0
# 2                       0.000000  0.000000                             9.0
# 3                       0.009791  0.000900                            18.0
# 4                       0.016354  0.002214                            31.0
#
#    ck_oo_numberOfPublicMethods  LDHH_cbo  WCHU_numberOfLinesOfCode  \
# 0                          6.0  0.023730                      1.15
# 1                          1.0  0.014303                      3.13
# 2                          1.0  0.000000                      0.00
# 3                         14.0  0.055485                      3.10
# 4                         12.0  0.032393                      2.04
#
#    CvsExpEntropy  LDHH_numberOfMethods     class
# 0       0.116244              0.019133  b'clean'
# 1       0.254718              0.000000  b'buggy'
# 2       0.000000              0.000000  b'buggy'
# 3       0.347682              0.001253  b'clean'
# 4       0.262198              0.000000  b'clean'
#
# [5 rows x 62 columns]

# %%
df.describe()
# Out:
#        ck_oo_numberOfPrivateMethods    LDHH_lcom   LDHH_fanIn  \
# count                   1862.000000  1862.000000  1862.000000
# mean                       1.016649     0.002510     0.007198
# std                        2.497982     0.008517     0.020142
# min                        0.000000     0.000000     0.000000
# 25%                        0.000000     0.000000     0.000000
# 50%                        0.000000     0.000000     0.000000
# 75%                        1.000000     0.000000     0.004101
# max                       24.000000     0.084635     0.239695
#
#        numberOfNonTrivialBugsFoundUntil:  WCHU_numberOfPublicAttributes  \
# count                        1862.000000                    1862.000000
# mean                            3.655209                       0.037997
# std                             5.981731                       0.275569
# min                             0.000000                       0.000000
# 25%                             1.000000                       0.000000
# 50%                             2.000000                       0.000000
# 75%                             4.000000                       0.000000
# max                            92.000000                       4.280000
#
#        WCHU_numberOfAttributes  CvsWEntropy  LDHH_numberOfPublicMethods  \
# count              1862.000000  1862.000000                 1862.000000
# mean                  0.469737     0.027583                    0.001983
# std                   1.238082     0.098073                    0.006888
# min                   0.000000     0.000000                    0.000000
# 25%                   0.000000     0.000949                    0.000000
# 50%                   0.000000     0.003069                    0.000000
# 75%                   0.000000     0.014775                    0.000000
# max                  18.270000     1.907710                    0.071222
#
#         WCHU_fanIn  LDHH_numberOfPrivateAttributes  ...  \
# count  1862.000000                     1862.000000  ...
# mean      1.007095                        0.002093  ...
# std       2.607637                        0.006982  ...
# min       0.000000                        0.000000  ...
# 25%       0.000000                        0.000000  ...
# 50%       0.000000                        0.000000  ...
# 75%       1.010000                        0.000000  ...
# max      38.270000                        0.083027  ...
#
#        numberOfBugsFoundUntil:  LDHH_fanOut  LDHH_numberOfMethodsInherited  \
# count              1862.000000  1862.000000                    1862.000000
# mean                  7.828679     0.007187                       0.007756
# std                  11.580764     0.014161                       0.010402
# min                   0.000000     0.000000                       0.000000
# 25%                   2.000000     0.000000                       0.000000
# 50%                   4.000000     0.000000                       0.005924
# 75%                   9.000000     0.008302                       0.009791
# max                 197.000000     0.136662                       0.089904
#
#           LDHH_rfc  ck_oo_numberOfMethodsInherited  \
# count  1862.000000                     1862.000000
# mean      0.006448                       14.527927
# std       0.016643                       18.173740
# min       0.000000                        0.000000
# 25%       0.000000                        0.000000
# 50%       0.000000                        9.000000
# 75%       0.005269                       18.000000
# max       0.179396                      226.000000
#
#        ck_oo_numberOfPublicMethods     LDHH_cbo  WCHU_numberOfLinesOfCode  \
# count                  1862.000000  1862.000000               1862.000000
# mean                      6.038131     0.013454                  1.714941
# std                       7.833720     0.025324                  3.387558
# min                       0.000000     0.000000                  0.000000
# 25%                       2.000000     0.000000                  0.000000
# 50%                       4.000000     0.003227                  0.000000
# 75%                       7.000000     0.016135                  2.080000
# max                      98.000000     0.249832                 35.590000
#
#        CvsExpEntropy  LDHH_numberOfMethods
# count    1862.000000           1862.000000
# mean        0.194479              0.002690
# std         0.156919              0.008887
# min         0.000000              0.000000
# 25%         0.005329              0.000000
# 50%         0.197267              0.000000
# 75%         0.299176              0.000000
# max         0.727558              0.086626
#
# [8 rows x 61 columns]

# %%
defect_true_false = df.groupby('class')['class'].apply(lambda x: x.count())
print(defect_true_false)
# Out:
# class
# b'buggy'     245
# b'clean'    1617
# Name: class, dtype: int64

# %%
df['class'].str.decode("utf-8")
# Out:
# 0       clean
# 1       buggy
# 2       buggy
# 3       clean
# 4       clean
#         ...
# 1857    clean
# 1858    clean
# 1859    clean
# 1860    clean
# 1861    clean
# Name: class, Length: 1862, dtype: object

# %%
X= df.iloc[ : , :-1].values
y= df['class'].str.decode("utf-8").map({'buggy': 1, 'clean': 0})

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
DecisionTree(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.7935656836461126
# F1 score:  0.5437707496068496
# Auc score:  0.5482868195634153

# %%
SVM(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8793565683646113
# F1 score:  0.4679029957203994
# Auc score:  0.49848024316109424

# %%
Logistic(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.871313672922252
# F1 score:  0.5650145772594752
# Auc score:  0.5529842497927604
# C:\Users\AdityaShankar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
Implicit_ME(X_train,y_train,X_test,y_test,10)
# Out:
# Accuracy of Mixture of Experts: 0.8766756032171582
# F1 score 0.5831389698736638
# AUC score 0.5658676429953026

# %%
Explicit_ME(X_train,y_train,X_test,y_test)
# Out:
# Accuracy of Mixture of Experts: 0.871313672922252
# F1 score 0.577815506508206
# AUC score 0.562828129317491

# %%
result = bagging(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.8766756032171582
# F1 score 0.606900659824047
# AUC score 0.5855554020447638

# %%
result = adaBoost(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.8659517426273459
# F1 score 0.5954797848342877
# AUC score 0.5794763746891406
