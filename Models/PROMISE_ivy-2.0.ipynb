# %%
import pandas as pd
from scipy.io import arff
from sklearn.model_selection import train_test_split 
from models import Implicit_ME
from models import Logistic
from models import SVM
from models import DecisionTree
from models import Explicit_ME
from ensemble_models import adaBoost
from ensemble_models import bagging

# %%
data = arff.loadarff('../dataSet/PROMISE/ivy-2.0.arff')

# %%
df = pd.DataFrame(data[0])
df.head()
# Out:
#     wmc  dit  noc   cbo   rfc   lcom    ca   ce   npm     lcom3  ...  \
# 0  28.0  1.0  0.0  32.0  82.0  374.0  26.0  7.0  24.0  1.012346  ...
# 1   6.0  1.0  2.0   3.0   7.0    3.0   2.0  1.0   4.0  0.600000  ...
# 2   4.0  2.0  0.0   5.0   6.0    4.0   1.0  4.0   2.0  0.666667  ...
# 3   4.0  1.0  0.0   9.0   4.0    6.0   9.0  0.0   4.0  2.000000  ...
# 4   1.0  1.0  0.0   8.0   1.0    0.0   6.0  2.0   1.0  2.000000  ...
#
#         dam  moa  mfa       cam   ic  cbm        amc  max_cc  avg_cc  defects
# 0  0.166667  0.0  0.0  0.226337  0.0  0.0  31.642857    23.0  2.6786      2.0
# 1  1.000000  0.0  0.0  0.444444  0.0  0.0   4.666667     1.0  0.6667      0.0
# 2  1.000000  1.0  0.5  0.500000  0.0  0.0   4.000000     1.0  0.5000      0.0
# 3  0.000000  0.0  0.0  0.666667  0.0  0.0   0.000000     1.0  1.0000      0.0
# 4  0.000000  0.0  0.0  1.000000  0.0  0.0   0.000000     1.0  1.0000      0.0
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#               wmc         dit         noc         cbo         rfc  \
# count  352.000000  352.000000  352.000000  352.000000  352.000000
# mean    11.284091    1.792614    0.369318   13.232955   34.036932
# std     15.148232    1.244773    1.318279   16.571085   44.679566
# min      1.000000    1.000000    0.000000    1.000000    1.000000
# 25%      3.000000    1.000000    0.000000    5.000000    6.000000
# 50%      6.000000    1.000000    0.000000    8.000000   19.000000
# 75%     13.000000    2.000000    0.000000   16.000000   40.000000
# max    157.000000    6.000000   17.000000  150.000000  312.000000
#
#                lcom          ca          ce         npm       lcom3  ...  \
# count    352.000000  352.000000  352.000000  352.000000  352.000000  ...
# mean     131.579545    6.880682    5.164773    9.036932    1.059352  ...
# std      712.192029   13.938917    8.931273   12.636099    0.660123  ...
# min        0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 25%        0.000000    1.000000    1.000000    2.000000    0.625000  ...
# 50%        6.000000    3.000000    2.000000    5.000000    0.850000  ...
# 75%       45.250000    6.000000    5.000000   11.000000    2.000000  ...
# max    11794.000000  147.000000   75.000000  142.000000    2.000000  ...
#
#               dam         moa         mfa         cam          ic         cbm  \
# count  352.000000  352.000000  352.000000  352.000000  352.000000  352.000000
# mean     0.616224    0.715909    0.290908    0.490831    0.357955    0.636364
# std      0.459940    1.441737    0.385164    0.254585    0.733601    1.781077
# min      0.000000    0.000000    0.000000    0.055223    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.299074    0.000000    0.000000
# 50%      1.000000    0.000000    0.000000    0.444444    0.000000    0.000000
# 75%      1.000000    1.000000    0.670918    0.666667    0.250000    0.250000
# max      1.000000   12.000000    1.000000    1.000000    4.000000   18.000000
#
#               amc      max_cc      avg_cc     defects
# count  352.000000  352.000000  352.000000  352.000000
# mean    18.489722    3.187500    1.214294    0.159091
# std     27.032755    3.848123    0.816136    0.498119
# min      0.000000    0.000000    0.000000    0.000000
# 25%      4.666667    1.000000    0.800000    0.000000
# 50%     10.388199    2.000000    1.000000    0.000000
# 75%     21.434615    4.000000    1.446925    0.000000
# max    203.500000   29.000000    6.500000    3.000000
#
# [8 rows x 21 columns]

# %%
X= df.iloc[ : , :-1].values
y= df['defects'].apply(lambda x : 1 if(x > 0) else 0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
DecisionTree(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8450704225352113
# F1 score:  0.5342874180083482
# Auc score:  0.5313620071684588

# %%
SVM(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8732394366197183
# F1 score:  0.46616541353383456
# Auc score:  0.5

# %%
Logistic(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8732394366197183
# F1 score:  0.46616541353383456
# Auc score:  0.5
# C:\Users\AdityaShankar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
Implicit_ME(X_train,y_train,X_test,y_test,10)
# Out:
# Accuracy of Mixture of Experts: 0.8732394366197183
# F1 score 0.46616541353383456
# AUC score 0.5

# %%
Explicit_ME(X_train,y_train,X_test,y_test)
# Out:
# Accuracy of Mixture of Experts: 0.8732394366197183
# F1 score 0.46616541353383456
# AUC score 0.5

# %%
result = bagging(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.8591549295774648
# F1 score 0.4621212121212121
# AUC score 0.49193548387096775

# %%
result = adaBoost(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.8732394366197183
# F1 score 0.46616541353383456
# AUC score 0.5
