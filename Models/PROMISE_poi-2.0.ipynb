# %%
import pandas as pd
from scipy.io import arff
from sklearn.model_selection import train_test_split 
from models import Implicit_ME
from models import Logistic
from models import SVM
from models import DecisionTree
from models import Explicit_ME
from ensemble_models import adaBoost
from ensemble_models import bagging

# %%
data = arff.loadarff('../dataSet/PROMISE/poi-2.0.arff')

# %%
df = pd.DataFrame(data[0])
df.head()
# Out:
#     wmc  dit  noc  cbo   rfc   lcom   ca   ce   npm     lcom3  ...       dam  \
# 0  23.0  1.0  0.0  5.0  46.0  123.0  1.0  4.0   4.0  0.659091  ...  1.000000
# 1  12.0  2.0  0.0  6.0  23.0   46.0  2.0  4.0  10.0  0.818182  ...  0.500000
# 2  15.0  2.0  0.0  6.0  35.0   41.0  3.0  4.0  13.0  0.690476  ...  0.666667
# 3  11.0  2.0  0.0  5.0  21.0   43.0  2.0  3.0   9.0  0.850000  ...  0.500000
# 4   4.0  1.0  0.0  8.0  17.0    0.0  3.0  5.0   3.0  0.000000  ...  1.000000
#
#    moa       mfa       cam   ic  cbm        amc  max_cc  avg_cc  defects
# 0  1.0  0.000000  0.267081  0.0  0.0  27.608696     8.0  2.3043      0.0
# 1  0.0  0.550000  0.400000  1.0  6.0   9.000000     2.0  0.8333      0.0
# 2  0.0  0.478261  0.516667  1.0  6.0  23.000000     2.0  1.1333      0.0
# 3  0.0  0.578947  0.418182  1.0  6.0   9.454545     2.0  1.0000      0.0
# 4  0.0  0.000000  0.500000  0.0  0.0  27.750000     2.0  1.2500      1.0
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#               wmc         dit         noc         cbo         rfc  \
# count  314.000000  314.000000  314.000000  314.000000  314.000000
# mean    14.302548    1.700637    0.742038    8.652866   29.646497
# std     13.859894    0.668458    7.667638   16.764404   33.404088
# min      0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      6.000000    1.000000    0.000000    4.000000   14.000000
# 50%     11.000000    2.000000    0.000000    5.000000   22.000000
# 75%     17.750000    2.000000    0.000000    7.000000   35.000000
# max    108.000000    5.000000  125.000000  156.000000  341.000000
#
#               lcom          ca          ce         npm       lcom3  ...  \
# count   314.000000  314.000000  314.000000  314.000000  314.000000  ...
# mean    103.764331    4.509554    4.477707   12.124204    0.967458  ...
# std     359.683321   14.502448    8.944333   11.651784    0.520454  ...
# min       0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 25%       3.000000    1.000000    2.000000    5.000000    0.743590  ...
# 50%      37.500000    2.000000    3.000000    9.500000    0.847447  ...
# 75%      72.000000    3.000000    4.000000   15.000000    1.097727  ...
# max    4268.000000  154.000000  121.000000   93.000000    2.000000  ...
#
#               dam         moa         mfa         cam          ic         cbm  \
# count  314.000000  314.000000  314.000000  314.000000  314.000000  314.000000
# mean     0.510279    0.971338    0.300182    0.423084    0.531847    2.614650
# std      0.390562    2.873667    0.281440    0.187193    0.518604    2.825247
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.312708    0.000000    0.000000
# 50%      0.500000    0.000000    0.300000    0.400000    1.000000    1.000000
# 75%      0.906818    1.000000    0.550000    0.500000    1.000000    6.000000
# max      1.000000   34.000000    1.000000    1.000000    2.000000    7.000000
#
#               amc      max_cc      avg_cc     defects
# count  314.000000  314.000000  314.000000  314.000000
# mean    18.129182    3.585987    1.150125    0.124204
# std     38.729724    7.636757    1.043991    0.349148
# min      0.000000    0.000000    0.000000    0.000000
# 25%      6.888889    1.000000    0.818200    0.000000
# 50%     12.435847    2.000000    0.945900    0.000000
# 75%     18.207500    3.000000    1.196875    0.000000
# max    614.062500  117.000000   14.222200    2.000000
#
# [8 rows x 21 columns]

# %%
X= df.iloc[ : , :-1].values
y= df['defects'].apply(lambda x : 1 if(x > 0) else 0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
DecisionTree(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.7777777777777778
# F1 score:  0.49886363636363634
# Auc score:  0.4988636363636364

# %%
SVM(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8888888888888888
# F1 score:  0.5811965811965811
# Auc score:  0.5625

# %%
Logistic(X_train,y_train,X_test,y_test)
# Out:
# Accuracy:  0.8412698412698413
# F1 score:  0.5982142857142857
# Auc score:  0.5886363636363636
# C:\Users\AdityaShankar\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
Implicit_ME(X_train,y_train,X_test,y_test,6)
# Out:
# Accuracy of Mixture of Experts: 0.873015873015873
# F1 score 0.6315789473684211
# AUC score 0.6068181818181818

# %%
Explicit_ME(X_train,y_train,X_test,y_test)
# Out:
# Accuracy of Mixture of Experts: 0.8571428571428571
# F1 score 0.6140231449965964
# AUC score 0.5977272727272728

# %%
result = bagging(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.8412698412698413
# F1 score 0.5394736842105263
# AUC score 0.5352272727272728

# %%
result = adaBoost(X_train,y_train,X_test,y_test)
print("Accuracy" , result["Accuracy"])
print("F1 score", result["F1_score"])
print("AUC score", result["AUC_score"])
# Out:
# Accuracy 0.873015873015873
# F1 score 0.5655172413793104
# AUC score 0.5534090909090909
